# %%
import os

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/cfotache/pytorch_custom_yolo_training.git

# %cd pytorch_custom_yolo_training 
# !mkdir data
# %cd data
# !mkdir seaship
# %cd seaship
# !mkdir images
# !mkdir labels
% cd ..
% cd ..
# Out:
# Cloning into 'pytorch_custom_yolo_training'...
# remote: Enumerating objects: 39, done.
# remote: Total 39 (delta 0), reused 0 (delta 0), pack-reused 39
# Unpacking objects: 100% (39/39), done.
# /content/pytorch_custom_yolo_training
# /content/pytorch_custom_yolo_training/data
# /content/pytorch_custom_yolo_training/data/seaship
# /content/pytorch_custom_yolo_training/data
# /content/pytorch_custom_yolo_training

# %%
% cd config
! wget https://pjreddie.com/media/files/yolov3.weights
% cd ..
# Out:
# /content/pytorch_custom_yolo_training/config
# --2020-03-05 17:08:56--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights       22%[===>                ]  53.02M   552KB/s    eta 6m 0s

# %%
# !cp  '/content/gdrive/My Drive/Seasships/ImageSets/Main/trainim.txt'  /content/pytorch_custom_yolo_training/data/seaship
# !cp  '/content/gdrive/My Drive/Seasships/ImageSets/Main/valim.txt'  /content/pytorch_custom_yolo_training/data/seaship
# !cp  '/content/gdrive/My Drive/Seasships/ImageSets/Main/seasship.data'  /content/pytorch_custom_yolo_training/config
# !cp  '/content/gdrive/My Drive/Seasships/ImageSets/Main/seasship.names'  /content/pytorch_custom_yolo_training/config
# !cp  '/content/gdrive/My Drive/Seasships/ImageSets/Main/yolov31.cfg'  /content/pytorch_custom_yolo_training/config
# !cp  '/content/gdrive/My Drive/Seasships/1-20.weights'  /content/pytorch_custom_yolo_training/config
# !cp  '/content/gdrive/My Drive/Seasships/ImageSets/Main/train.py'  /content/pytorch_custom_yolo_training
# !cp  '/content/gdrive/My Drive/Seasships/ImageSets/Main/trainw.py'  /content/pytorch_custom_yolo_training

# %%
# !cp -a -v '/content/gdrive/My Drive/Seasships/images/.'  /content/pytorch_custom_yolo_training/data/seaship/images/
# !cp -a -v '/content/gdrive/My Drive/Seasships/labels/.'  /content/pytorch_custom_yolo_training/data/seaship/labels/
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# '/content/gdrive/My Drive/Seasships/images/./001058.jpg' -> '/content/pytorch_custom_yolo_training/data/seaship/images/./001058.jpg'
# '/content/gdrive/My Drive/Seasships/images/./001053.jpg' -> '/content/pytorch_custom_yolo_training/data/seaship/images/./001053.jpg'
# '/content/gdrive/My Drive/Seasships/images/./001055.jpg' -> '/content/pytorch_custom_yolo_training/data/seaship/images/./001055.jpg'
# '/content/gdrive/My Drive/Seasships/images/./001050.jpg' -> '/content/pytorch_custom_yolo_training/data/seaship/images/./001050.jpg'
# '/content/gdrive/My Drive/Seasships/images/./001049.jpg' -> '/content/pytorch_custom_yolo_training/data/seaship/images/./001049.jpg'
# '/content/gdrive/My Drive/Seasships/images/./001051.jpg' -> '/content/pytorch_custom_yolo_training/data/seaship/images/./001051.jpg'
# ...

# %%
#@title Titre par défaut
#!python train.py --epochs 100 --batch_size 16 --image_folder "data/seaship/images" --model_config_path "config/yolov31.cfg" --data_config_path "config/seasship.data" --class_path "config/seasship.names" --checkpoint_interval 20 --checkpoint_dir '/content/gdrive/My Drive/Seasships'
# !python trainw.py --epochs 150 --batch_size 16 --weights_path "config/1-20.weights" --image_folder "data/seaship/images" --model_config_path "config/yolov31.cfg" --data_config_path "config/seasship.data" --class_path "config/seasship.names" --checkpoint_interval 10 --checkpoint_dir '/content/gdrive/My Drive/Seasships'
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# ...
# [Epoch 8/150, Batch 47/110] [Losses: x 0.201121, y 0.235149, w 0.076756, h 0.150513, conf 0.323560, cls 0.278141, total 1.265241, recall: 0.50000, precision: 0.02394]
# ...
# [Epoch 8/150, Batch 48/110] [Losses: x 0.169743, y 0.067425, w 0.121530, h 0.088364, conf 0.144492, cls 0.279206, total 0.870759, recall: 0.43750, precision: 0.02919]
# ...
# [Epoch 8/150, Batch 49/110] [Losses: x 0.249828, y 0.062190, w 0.148985, h 0.094034, conf 0.171693, cls 0.282649, total 1.009380, recall: 0.54167, precision: 0.02736]
# ...
# [Epoch 8/150, Batch 50/110] [Losses: x 0.165460, y 0.069032, w 0.062750, h 0.084045, conf 0.190134, cls 0.290289, total 0.861710, recall: 0.45833, precision: 0.02331]
# ...
# [Epoch 8/150, Batch 51/110] [Losses: x 0.151893, y 0.137346, w 0.040079, h 0.122967, conf 0.181244, cls 0.272192, total 0.905721, recall: 0.68750, precision: 0.03768]
# ...

# %%
#%cd checkpoints
#!ls
#!cp  '/content/gdrive/My Drive/Seasships/ImageSets/Main/19.weights'  /content/pytorch_custom_yolo_training/config
#%cd ..
#!cp  /content/pytorch_custom_yolo_training/checkpoints/19.weights   '/content/gdrive/My Drive/Seasships/ImageSets/Main'
